# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('airbnb_nyc.csv')
df.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
#
#   rating reviews    host_name      host_id                   address  \
# 0   4.71      64    Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0        Fatih  386223873.0      Kaş, Antalya, Turkey
# 2   4.85      68       Giorgi  409690853.0          Imereti, Georgia
# 3    5.0      13        Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4    New       0  Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# ...

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
print(df)
# Out:
#        Unnamed: 0                  id  \
# 0               0            49849504
# 1               1            50891766
# 2               2            50699164
# 3               3            49871422
# 4               4            51245886
# ...           ...                 ...
# 12799       12799  640474109823176234
# 12800       12800            44697740
# 12801       12801            29975283
# 12803       12803             8006146
# 12804       12804            40547903
#
#                                                     name rating reviews  \
# 0                                         Perla bungalov   4.71      64
# 1      Authentic Beach Architect Sheltered Villa with...    New       0
# 2                                      cottages sataplia   4.85      68
# 3                            Sapanca Breathable Bungalow    5.0      13
# 4                                          Bungalov Ev 2    New       0
# ...

# %% [markdown]
# SANITY CHECK : SHAPE , INFO

# %%
df.shape
# Out:
# (10189, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10189 entries, 0 to 12804
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    10189 non-null  int64
#  1   id            10189 non-null  int64
#  2   name          10189 non-null  object
#  3   rating        10189 non-null  object
#  4   reviews       10189 non-null  object
#  5   host_name     10189 non-null  object
#  6   host_id       10189 non-null  float64
#  7   address       10189 non-null  object
#  8   features      10189 non-null  object
#  9   amenities     10189 non-null  object
#  10  safety_rules  10189 non-null  object
#  11  hourse_rules  10189 non-null  object
#  12  img_links     10189 non-null  object
#  13  price         10189 non-null  int64
#  14  country       10189 non-null  object
#  15  bathrooms     10189 non-null  int64
#  16  beds          10189 non-null  int64
#  17  guests        10189 non-null  int64
# ...

# %% [markdown]
# FINDING MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# id              0
# name            0
# rating          0
# reviews         0
# host_name       0
# host_id         0
# address         0
# features        0
# amenities       0
# safety_rules    0
# hourse_rules    0
# img_links       0
# price           0
# country         0
# bathrooms       0
# beds            0
# guests          0
# toiles          0
# bedrooms        0
# studios         0
# checkin         0
# checkout        0
# dtype: int64

# %% [markdown]
# FINDING DUPLICATES

# %%
df.duplicated().sum()
# Out:
# 0
